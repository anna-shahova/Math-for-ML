# %% [markdown]
# ## Bias-variance trade off visualized

# %% [markdown]
# ## Imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Parameters

# %%
# Frontmatter

np.random.seed(123)
MARKER_SIZE = 100
DATA_COLOR = 'black'
ERROR_COLOR = 'darkred'
POLYNOMIAL_FIT_COLORS = ['orange', 'royalblue', 'darkgreen']
LEGEND_FONTSIZE = 14
TITLE_FONTISIZE = 16
N_OBSERVATIONS = 100
NOISE_STD = 0.75

# %% [markdown]
# ## Generate data

# %%
x = 2 * (np.random.rand(N_OBSERVATIONS) - .5)
x_grid = np.linspace(-1,1 , 200)


def f(x):
    """Base function"""
    return np.sin(x * np.pi)


def sample_fx_data(shape, noise_std=NOISE_STD):
    return f(x) + np.random.randn(*shape) * noise_std


def plot_fx_data(y=None):
    """Plot f(x) and noisy samples"""
    y = y if y is not None else sample_fx_data(x.shape)
    fig, axs = plt.subplots(figsize=(6, 6))
    plt.plot(x_grid, f(x_grid), color=DATA_COLOR, label='f(x)')
    plt.scatter(x, y, s=MARKER_SIZE, edgecolor=DATA_COLOR, facecolors='none', label='y')


# Plot the data
y = sample_fx_data(x.shape)
plot_fx_data(y)
plt.legend(fontsize=14)
plt.title(f'$f(x) = sin(\pi x)$ and some observations, $y$', fontsize=16)
plt.xlim([-1, 1])
plt.ylim([-2, 2])
# Out:
# (-2.0, 2.0)

# %% [markdown]
# ## Visualization of different polynomials fits

# %%
plot_fx_data(y)

polynomial_degrees = [1,3,10]
theta = {}
fit = {}
for ii, degree in enumerate(polynomial_degrees):
    # Note: we should get an overconditioned warning for degree 10 because of extreme overfitting
    theta[degree] = np.polyfit(x, y, degree)
    fit[degree] = np.polyval(theta[degree], x_grid)
    plt.plot(x_grid, fit[degree], POLYNOMIAL_FIT_COLORS[ii], label=f"$g_{degree}(x)$")
plt.legend(fontsize=LEGEND_FONTSIZE)
plt.xlim([-1, 1])
plt.ylim([-2, 2])
plt.title("Various Polynomial Functions Fit to Observations", fontsize=TITLE_FONTISIZE)
# Out:
# Text(0.5, 1.0, 'Various Polynomial Functions Fit to Observations')

# %%
from collections import defaultdict

n_simulations = 50
simulation_fits = defaultdict(list)
for sim in range(n_simulations):
    # Start from same samples
    y_simulation = sample_fx_data(x.shape)
    for degree in polynomial_degrees:
        # Note: we should get an overconditioned warning
        # for degree 10 because of extreme overfitting
        theta_tmp = np.polyfit(x, y_simulation, degree)
        simulation_fits[degree].append(np.polyval(theta_tmp, x_grid))


def error_function(pred, actual):
    return (pred - actual) ** 2


fig, axs = plt.subplots(1, 3, figsize=(15, 5))
for ii, degree in enumerate(polynomial_degrees):
    plt.sca(axs[ii])
    for jj, fit in enumerate(simulation_fits[degree]):
        label = 'Single Simulation Model Fit' if jj == 0 else None
        plt.plot(x_grid, fit, color=POLYNOMIAL_FIT_COLORS[ii], alpha=.1, label=label)

    average_fit = np.array(simulation_fits[degree]).mean(0)
    squared_error = error_function(average_fit, f(x_grid))
    rms = np.sqrt((squared_error.mean()))
    plt.plot(x_grid, average_fit, color=POLYNOMIAL_FIT_COLORS[ii], linewidth=3, label='Average Model')
    plt.plot(x_grid, squared_error, '--', color=ERROR_COLOR, label='Squared Error')
    plt.plot(x_grid, f(x_grid), color='black', label='f(x)')
    plt.yticks([])
    if ii == 1:
        plt.xlabel('x')
    elif ii == 0:
        plt.ylabel('y')
        plt.yticks([-2, 0, 2])

    plt.xlim([-1, 1])
    plt.ylim([-2, 2])
    plt.xticks([-1, 0, 1])
    plt.title(f"$g_(x)$ : RMS Error={np.round(rms, 1)}")
    plt.legend(loc='lower right')
plt.suptitle('Model Fits Given Random Samples Around f(x)', fontsize=TITLE_FONTISIZE)
# Out:
# Text(0.5, 0.98, 'Model Fits Given Random Samples Around f(x)')

# %% [markdown]
# ### Questions
#
# On a visualization below we train three polynomial models.
# Each model is trained 50 times on a randomly generated different training dataset.
# Shallow lines show a performance of a single model, while the thick line show mean of all the models
#
# 1. Based on the visualization, which model has the largest and smallest variance? How did you make this conclusion?
# 2. Which has the largest and smallest bias?
# 3. If you would need to fit a single polynome model on one training dataset, which model you would choose out of these three?

# %% [markdown]
# Ответ:
# 1. Наибольшую дисперсию имеет модель с полиномом 10 степени. Это видно по графику, так как линии достаточно сильно рабросаны вокруг среднего значения. Наименьшую дисперсию достаточно сложно определить по графику с полиномами 1 и 3 степени. Если исходить из первого графика, что значения ближе к -1 и 1 достаточно сильно разбросаны, нобольшинство линий находится вокруг среднего, поэтому можно предположить, что модель с полиномом первой степени имеет наименьшую дисперсию.
# 2. Наибольшую ошибку RMSE имеет модель с полиномом первой степени, наименьшую с полиномом 10 степени.
# 3. Если выбирать одну модель для нового набора данных, то необходимо выбрать модель с полиномом 3 степени (график 2). По соотношению bias-variance она хорошо подойдет, тк не склонна к переобучению и при этом не будет плохо обучаема.

# %% [markdown]
# ## Exercise 2: Regression, overfitting and trees

# %% [markdown]
# ### Imports

# %%
import numpy as np
import matplotlib.pyplot as plt
from random import randint
from math import pi as PI
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split

plt.style.use('ggplot')

# for reproducibility across different runs, one may set a seed as follows:
np.random.seed(42)

# %% [markdown]
# ### Task 1
#
# In the code below generate a random noise vector of length NUM_OBS using np.random.normal function and add the noise to the target variable
#
# Docs: https://numpy.org/doc/stable/reference/random/generated/numpy.random.normal.html

# %%
# number of observations
NUM_OBS = 150

# predictors
x = np.linspace(0, 4, num = NUM_OBS)
# noise
eps = np.random.normal(size = NUM_OBS) #Generate noise
# outcome
y = np.sin(PI*x) + eps #Add noise

# %%
fig = plt.figure(figsize=(7,7))
ax = plt.axes()
ax.set_title('y = sin(πx) + Ɛ')
ax.set_xlabel("x")
ax.set_ylabel("y")

ax.scatter(x, y, c = 'k')

# %% [markdown]
# ### Task 2
#
# Create test train split using sklearn train_test_split function with test size 20%
# You can search the docs for train_test_split in https://scikit-learn.org/stable/ or search in earlier homeworks

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2)

# %%
a=pd.DataFrame()
a['x_train']=x_train
a['y_train']=y_train
a=a.sort_values(by='x_train')
x_train=a['x_train'].values
y_train=a['y_train'].values

a=pd.DataFrame()
a['x_test']=x_test
a['y_test']=y_test
a=a.sort_values(by='x_test')
x_test=a['x_test'].values
y_test=a['y_test'].values

# %% [markdown]
# ### Task 3
#
# The code below visulizes training set.
# Add test set visualization in the same figure and label it "Train set"

# %%
fig = plt.figure(figsize = (7,7))
ax = plt.axes()
ax.set_title('y = sin(πx) + Ɛ')
ax.set_xlabel("x")
ax.set_ylabel("y")

ax.scatter(x_train, y_train, label = "Train set")
ax.scatter(x_test, y_test, label = "Test set") #Your code here
ax.legend()

# %% [markdown]
# ## Fitting polynomial

# %% [markdown]
# In the task below we fit a polynom into the training and testing dataset, visualize the error and print MSE
#
# Task: Changing k either manually or by constructing for loop, describe how does error for test and train behave as k grows.
#
# Is there a value of k, when it does not make sense to grow it anymore. Why?

# %% [markdown]
# NOTE: If you did everything correct so far your plot will look similar to the one which is now printed under the cell

# %%
fig, axs = plt.subplots(1, 2, figsize = (18,7))

axs[0].set_title('Train Set Predictions')
axs[1].set_title('Test Set Predictions')

axs[0].set_xlabel("x train")
axs[0].set_ylabel("y")
axs[0].set_ylim([-3, 3])

axs[1].set_xlabel("x test")
axs[1].set_ylabel("y")
axs[1].set_ylim([-3, 3])

axs[0].scatter(x_train, y_train, c = 'k', label = "y train")
axs[1].scatter(x_test, y_test, c = 'k', label = "y test")



k=17

# k-th degree polynomial coefficients
fit_coeff = np.polyfit(x_train, y_train, deg = k+1)

# train and test k-th degree polynomial fit
y_train_pred = np.polyval(fit_coeff, x_train)
y_test_pred = np.polyval(fit_coeff, x_test)

# train and test MSE of k-th degree polynomial fit
iter_train_mse = mean_squared_error(y_train_pred, y_train)
iter_test_mse = mean_squared_error(y_test_pred, y_test)

# plot train and test k-th degree polynomial fit
axs[0].plot(x_train,
                y_train_pred,
                color = 'red',
                label = "deg: {}".format(k+1))

axs[1].plot(x_test,
                y_test_pred,
                color = 'red',
                label = "deg: {}".format(k+1))

print(f"""Train MSE {iter_train_mse} Test MSE {iter_test_mse}""")
# Out:
# Train MSE 0.8085869868416701 Test MSE 1.0088765215715751

# %% [markdown]
# Ответ:
# При k, равном 17 модель перестала обучаться и стала склонна к переобучению, что делает модель более не пригодной, так как она хорошо обучилась на тестовых данных и не воспринимает тестовые. Не имеет смысла повышать значение больше этого коэффициента.

# %% [markdown]
# ## Fitting regression tree

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor

# %%
x_train=x_train.reshape(-1, 1)
y_train=y_train.reshape(-1, 1)
x_test=x_test.reshape(-1, 1)
y_test=y_test.reshape(-1, 1)

# %% [markdown]
# ### Task 4
#
# Add DecisionTreeRegressor as a model below and try different max_depth values. What happens as you increase max_depth parameter in the tree?
# You can search the docs for DecisionTreeRegressor in https://scikit-learn.org/stable/

# %%
fig, axs = plt.subplots(1, 2, figsize = (18,7))

axs[0].set_title('Train Set Predictions')
axs[1].set_title('Test Set Predictions')

axs[0].set_xlabel("x train")
axs[0].set_ylabel("y")
axs[0].set_ylim([-3, 3])

axs[1].set_xlabel("x test")
axs[1].set_ylabel("y")
axs[1].set_ylim([-3, 3])

axs[0].scatter(x_train, y_train, c = 'k', label = "y train")
axs[1].scatter(x_test, y_test, c = 'k', label = "y test")


# k-th degree polynomial coefficients

max_depth_values = [2, 5, 10, 20]
for max_depth in max_depth_values:
  model = DecisionTreeRegressor(max_depth=max_depth)
  model.fit(x_train.reshape(-1, 1), y_train)


  # train and test k-th degree polynomial fit
  y_train_pred = model.predict(x_train)
  y_test_pred = model.predict(x_test)

  # train and test MSE of k-th degree polynomial fit
  iter_train_mse = mean_squared_error(y_train_pred, y_train)
  iter_test_mse = mean_squared_error(y_test_pred, y_test)

  # plot train and test k-th degree polynomial fit
  axs[0].plot(x_train,
                  y_train_pred,
                  color = 'red',
                  label = "deg: {}".format(k+1))

  axs[1].plot(x_test,
                  y_test_pred,
                  color = 'red',
                  label = "deg: {}".format(k+1))

  print(f"Max Depth: {max_depth} - Train MSE: {iter_train_mse}, Test MSE: {iter_test_mse}")
# Out:
# Max Depth: 2 - Train MSE: 1.0582073364564113, Test MSE: 0.845463883733557
# Max Depth: 5 - Train MSE: 0.5586904729153697, Test MSE: 1.206473866621028
# Max Depth: 10 - Train MSE: 0.02658929443038809, Test MSE: 1.5873389292432079
# Max Depth: 20 - Train MSE: 0.0, Test MSE: 1.5839912340079159

# %% [markdown]
# Ответ:
# Когда мы увеличиваем параметр max_depth, модель переобучается на тестовых данных. На графике явно видно, что при значении 20 модель полностью обучилась на тренировочных данных с нулевой ошибкой, однако абсолютно не способна дать хорошего результата на тестовых данных.

# %% [markdown]
# ### Task 4
#
# Copy the full code in the cell below and replace the model with RandomForestRegressor
#
# Try different n_estimators and max_depth.
# What happens to prediction as we increase n_estimators? Why?
#
# If you have same max depth for the normal tree above and the radom forest which of them predicts better?
# Is fitted function more smooth for forest or for the normal tree? Why?

# %%
fig, axs = plt.subplots(1, 2, figsize = (18,7))

axs[0].set_title('Train Set Predictions')
axs[1].set_title('Test Set Predictions')

axs[0].set_xlabel("x train")
axs[0].set_ylabel("y")
axs[0].set_ylim([-3, 3])

axs[1].set_xlabel("x test")
axs[1].set_ylabel("y")
axs[1].set_ylim([-3, 3])

axs[0].scatter(x_train, y_train, c = 'k', label = "y train")
axs[1].scatter(x_test, y_test, c = 'k', label = "y test")


max_depth_values = [2, 5, 10, 20]
for max_depth in max_depth_values:
  model = RandomForestRegressor(max_depth=max_depth, n_estimators=100)# Add you code here
  model.fit(x_train.reshape(-1, 1), y_train)


  # train and test k-th degree polynomial fit
  y_train_pred = model.predict(x_train)
  y_test_pred = model.predict(x_test)

  # train and test MSE of k-th degree polynomial fit
  iter_train_mse = mean_squared_error(y_train_pred, y_train)
  iter_test_mse = mean_squared_error(y_test_pred, y_test)

  # plot train and test k-th degree polynomial fit
  axs[0].plot(x_train,
                  y_train_pred,
                  color = 'red',
                  label = "deg: {}".format(k+1))

  axs[1].plot(x_test,
                  y_test_pred,
                  color = 'red',
                  label = "deg: {}".format(k+1))

  print(f"Max Depth: {max_depth} - Train MSE: {iter_train_mse}, Test MSE: {iter_test_mse}")
# Out:
# <ipython-input-54-7be7425e0314>:21: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   model.fit(x_train.reshape(-1, 1), y_train)
# <ipython-input-54-7be7425e0314>:21: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   model.fit(x_train.reshape(-1, 1), y_train)
# Max Depth: 2 - Train MSE: 0.9152152012721722, Test MSE: 0.7566028310453375
# Max Depth: 5 - Train MSE: 0.5037163703678703, Test MSE: 0.8878879095022919
# <ipython-input-54-7be7425e0314>:21: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   model.fit(x_train.reshape(-1, 1), y_train)
# <ipython-input-54-7be7425e0314>:21: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   model.fit(x_train.reshape(-1, 1), y_train)
# Max Depth: 10 - Train MSE: 0.21461120790789592, Test MSE: 1.0868250872284906
# Max Depth: 20 - Train MSE: 0.20780385106429827, Test MSE: 1.103652598344856

# %% [markdown]
# Ответ:
# По мере роста n_estimators, модель показывает результаты лучше.
#
# При сравнении двух моделей, случайный лес показывает результаты ошибок лучше. Это связано с тем, что случайный лес основан на агрегации прогнозов нескольких деревьев, что помогает снизить переобучение.
#
# Полученная функция также более плавная для случайного леса по сравнению с деревом решений. Это объясняется усредняющим эффектом из нескольких деревьев в случайном лесе, что приводит к более стабильному и плавному общему прогнозу.
